# %% [markdown]
# # CIE - 3                           Data Analysis Using Python

# %% [markdown]
# ## Ketan Rajkumar Sali

# %% [markdown]
# ## SRN - 202001094

# %% [markdown]
# #### Here we choose basketball data and apply multiple linear regression to predict
# #### Average point score per game from four independent variable

# %% [markdown]
# ### 1. Import dataset into python

# %%
import pandas as pd

# %%
import numpy as np

# %%
basketball=pd.read_csv(r"C:\Users\Master Ketan\OneDrive\Documents\MSc\Semister 2\Python\Basketball.csv")

# %%
basketball.head()
# Out:
#    (X1) height in feet  (X2) weight in pounds  \
# 0                  6.8                    225
# 1                  6.3                    180
# 2                  6.4                    190
# 3                  6.2                    180
# 4                  6.9                    205
#
#    (X3) percent of successful field goals  \
# 0                                   0.442
# 1                                   0.435
# 2                                   0.456
# 3                                   0.416
# 4                                   0.449
#
#    (X4)  percent of successful free throws  (Y) average points scored per game
# 0                                    0.672                                 9.2
# 1                                    0.797                                11.7
# 2                                    0.761                                15.8
# 3                                    0.651                                 8.6
# ...

# %% [markdown]
# ### 2. Visualization of data

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.histplot(basketball['(Y) average points scored per game'])
# Out:
# <AxesSubplot:xlabel='(Y) average points scored per game', ylabel='Count'>

# %%
sns.pairplot(basketball)

# %% [markdown]
# ### 3. output generated by sklearn

# %%
from sklearn import linear_model

# %%
X=basketball.loc[:,'(X1) height in feet':'(X4) percent of successful free throws']

# %%
Y=basketball['(Y) average points scored per game']

# %%
regr=linear_model.LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ### 4. Predicted output using sklearn

# %%
Predict_scores=regr.predict([[6.3,185,0.374,0.709]])

# %%
print(Predict_scores)
# Out:
# [8.64006433]

# %% [markdown]
# ### 5. Displays a comprehensive table with statistical info generated by statsmodels.

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(Y,X).fit()

# %%
predictions=model.predict(X)

# %%
print_model=model.summary()

# %%
print(print_model)
# Out:
#                                          OLS Regression Results
# ...
# Dep. Variable:     (Y) average points scored per game   R-squared (uncentered):                   0.846
# Model:                                            OLS   Adj. R-squared (uncentered):              0.834
# Method:                                 Least Squares   F-statistic:                              68.86
# Date:                                Wed, 07 Jul 2021   Prob (F-statistic):                    1.02e-19
# Time:                                        20:31:37   Log-Likelihood:                         -165.22
# No. Observations:                                  54   AIC:                                      338.4
# Df Residuals:                                      50   BIC:                                      346.4
# Df Model:                                           4
# Covariance Type:                            nonrobust
# ...
